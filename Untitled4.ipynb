# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0501/VITBML-EDA1/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# we got the data set from the online source:https://www.kaggle.com/karangadiya/fifa19
# 1.  what is the maximum wage recieved by a player?
# 2.what is the minimum wage recieved by a player?
# 1.   which jersey number is used by most player?
# 2.maximum repition recieved by a player?
# 1.minimum repition recieved by a player?
# 2.   which player has maximum skills?
# 1.which player has maximum weak foot?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pp=pd.read_csv('data.csv.zip')
pp
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 3               3  193080  ...       94.0         €138.6M
# 4               4  192985  ...       13.0         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [18207 rows x 89 columns]

# %%
pp.mean
# Out:
# <bound method DataFrame.mean of        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 3               3  193080  ...       94.0         €138.6M
# 4               4  192985  ...       13.0         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [18207 rows x 89 columns]>

# %% [markdown]
# The variables in the dataset are:
# *
# *

# %%
pp.median
# Out:
# <bound method DataFrame.median of        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 3               3  193080  ...       94.0         €138.6M
# 4               4  192985  ...       13.0         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [18207 rows x 89 columns]>

# %%
pp.mode
# Out:
# <bound method DataFrame.mode of        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0               0  158023  ...        8.0         €226.5M
# 1               1   20801  ...       11.0         €127.1M
# 2               2  190871  ...       11.0         €228.1M
# 3               3  193080  ...       94.0         €138.6M
# 4               4  192985  ...       13.0         €196.4M
# ...           ...     ...  ...        ...             ...
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [18207 rows x 89 columns]>

# %%
pp.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
pp.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
pp['Wage'].max()
# Out:
# '€9K'

# %%
pp['Wage'].min()
# Out:
# '€0'

# %%
pp['Jersey Number'].mode()
# Out:
# 0    8.0
# dtype: float64

# %%
pp['International Reputation'].max()
# Out:
# 5.0

# %%
pp['International Reputation'].min()
# Out:
# 1.0

# %%
pp['Skill Moves'].max()
# Out:
# 5.0

# %%
pp['Weak Foot'].max()
# Out:
# 5.0

# %%
a=pp['Skill Moves']
b=pp['Weak Foot']
plt.plot(a,label='line one',color='r',marker='o',markerfacecolor='r')
plt.plot(b,label='line two',color='g',marker='o',markerfacecolor='g')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.legend()
plt.title('line plot')
plt.grid(True,color='k',linestyle='--')
plt.show()

# %%
a=pp['Weak Foot']
c=range(1,100)
plt.hist(a,c,label='bar one',rwidth=0.8,color='g')
plt.title('histogram')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
a=pp['Weak Foot']
b=pp['Skill Moves']
plt.scatter(a,b,label='line one ',color='r',marker='o')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.legend(loc='upper right')
plt.title('scatter plot')
plt.grid(True,color='k',linestyle='--')
plt.show()
